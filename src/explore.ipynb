# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()

# Get credential values
client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
spotify = spotipy.Spotify(auth_manager=auth_manager)

# 2fZnIGcmeZuhplsTcCBmvD Cocofunka

#Obtener las mejores canciones del artista
results= spotify.artist_top_tracks("2fZnIGcmeZuhplsTcCBmvD") 

songs= []

for track in results ['tracks']:
    songs.append({"name":track['name'],
                  "popularity":track['popularity'],
                  "duracion_min":track['duration_ms']/60000})
    
print(songs)

df = pd.DataFrame(songs)

print(df)
# Out:
# [{'name': 'Pa Romper la Rutina', 'popularity': 40, 'duracion_min': 3.9191}, {'name': 'Suele Suceder', 'popularity': 36, 'duracion_min': 4.018433333333333}, {'name': 'Mejor Será', 'popularity': 35, 'duracion_min': 3.4488833333333333}, {'name': 'Asturión', 'popularity': 34, 'duracion_min': 4.241533333333333}, {'name': 'Donde Vamos', 'popularity': 33, 'duracion_min': 3.620433333333333}, {'name': 'Chúcaro', 'popularity': 32, 'duracion_min': 3.8975}, {'name': 'Toys & Guns', 'popularity': 31, 'duracion_min': 3.4551166666666666}, {'name': 'Mileidi', 'popularity': 31, 'duracion_min': 3.2678166666666666}, {'name': 'Siente', 'popularity': 31, 'duracion_min': 2.957333333333333}, {'name': 'Coleccionista', 'popularity': 29, 'duracion_min': 3.9016333333333333}]
#                   name  popularity  duracion_min
# 0  Pa Romper la Rutina          40      3.919100
# 1        Suele Suceder          36      4.018433
# 2           Mejor Será          35      3.448883
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(df['duracion_min'], df['popularity'])
plt.show()

# %%
# En el siguiente grafico existe una relacion de que las canciones de menor duracion en minutos tienen mas popularidad.

# %%
track_ids = [track["id"] for track in results["tracks"]]
features = spotify.audio_features(track_ids)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/urllib3/connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     464         except BaseException as e:
#     465             # Remove the TypeError from the exception chain in
#     466             # Python 3 (including for exceptions like SystemExit).
#     467             # Otherwise it looks like a bug in the code.
# --> 468             six.raise_from(e, None)
#     469 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/.local/lib/python3.11/site-packages/urllib3/connectionpool.py:463, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462 try:
# ...
